# %% [markdown]
# Histogram
#     A summary of variation in measured variable
#     frequency distrubutor
#     Bins the entire range of data into a series of interval and then count values in each intervals

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Ex_Files_Python_for_Data_Vis/Exercise Files/Common Plot Applications/data/kingCountyHouseData.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df['price'].head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
df['price'].hist()
## Plot not readable
# Out:
# <AxesSubplot: >

# %%
df['price'].hist()
plt.xticks(rotation=90)
# Out:
# (array([-1000000.,        0.,  1000000.,  2000000.,  3000000.,  4000000.,
#          5000000.,  6000000.,  7000000.,  8000000.,  9000000.]),
#  [Text(-1000000.0, 0, '−1'),
#   Text(0.0, 0, '0'),
#   Text(1000000.0, 0, '1'),
#   Text(2000000.0, 0, '2'),
#   Text(3000000.0, 0, '3'),
#   Text(4000000.0, 0, '4'),
#   Text(5000000.0, 0, '5'),
#   Text(6000000.0, 0, '6'),
#   Text(7000000.0, 0, '7'),
#   Text(8000000.0, 0, '8'),
#   Text(9000000.0, 0, '9')])

# %%
## can also use seaborn style as all the plot styles have few default setting which can be benefitial
plt.style.use('seaborn')
df['price'].hist(bins=100)
# Out:
# /tmp/ipykernel_283448/662762469.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <AxesSubplot: >

# %%
## mostly we are always interested in getting subset of the entire data set
price_filter = df.loc[:,'price'] <= 3000000
df.loc[price_filter,'price'].hist(bins=30)
# Out:
# <AxesSubplot: >

# %%
price_filter = df.loc[:,'price'] <= 3000000
df.loc[price_filter,'price'].hist(bins=30,
                                  edgecolor='black')
# Out:
# <AxesSubplot: >
